# %%
import pickle
import numpy as np

# %%
path = '../result/predictions/XGB_PREDS.binaryfile'
with open(path, 'rb') as f:
    XGB_PREDS = pickle.load(f)

# %%
va_pred, te_preds = XGB_PREDS[0]

# %%
te_preds
# Out:
# [array([0.99391234, 0.94771206, 0.03940129, 0.9807617 , 0.99184835,
#         0.00654047, 0.99593276, 0.00496844, 0.00611168, 0.9947271 ,
#         0.98928285, 0.550387  , 0.99618715, 0.08449464, 0.99660057,
#         0.1340051 , 0.9736878 , 0.9704498 , 0.06251129, 0.43152475,
#         0.9941286 , 0.9343532 , 0.990764  , 0.31324032, 0.861843  ,
#         0.00822762, 0.9681248 , 0.9959919 , 0.5864018 , 0.00596305,
#         0.0055313 , 0.9957216 , 0.01656125, 0.9960835 , 0.9951703 ,
#         0.00516386, 0.00957011, 0.9962572 , 0.01403244, 0.9959323 ,
#         0.00430935, 0.03689638, 0.00791014, 0.99520516, 0.99660933,
#         0.99137384, 0.9956678 , 0.9964438 , 0.01442101, 0.00390418,
#         0.00420589, 0.01581642, 0.03741083, 0.01291886, 0.00457173,
#         0.98867303, 0.01443999, 0.9920225 , 0.9964269 , 0.9957059 ,
#         0.9941499 , 0.0048603 , 0.9770289 , 0.99556446, 0.9943018 ,
#         0.00512877, 0.09098304, 0.00708245, 0.9857041 , 0.00618008,
# ...

# %%
y_pred = np.mean(te_preds, axis=0)
y_true =
# Out:
# array([0.9968897 , 0.86163723, 0.0263391 , 0.98211163, 0.9811198 ,
#        0.00331381, 0.99770653, 0.0026872 , 0.00269568, 0.99599683,
#        0.99435025, 0.6462181 , 0.9984082 , 0.06278349, 0.9985898 ,
#        0.17279775, 0.9721793 , 0.9602348 , 0.0197452 , 0.59237117,
#        0.9963638 , 0.9534931 , 0.995238  , 0.15383175, 0.84244287,
#        0.00428842, 0.9747238 , 0.9975642 , 0.54398954, 0.00271638,
#        0.0025729 , 0.99681073, 0.00968373, 0.9977678 , 0.9972971 ,
#        0.00205976, 0.00382398, 0.9977868 , 0.00769005, 0.995891  ,
#        0.00241987, 0.01233314, 0.003179  , 0.9966208 , 0.99832803,
#        0.9939704 , 0.9974682 , 0.99823856, 0.00551113, 0.00215573,
#        0.00194961, 0.01028417, 0.0149005 , 0.00430667, 0.00280985,
#        0.9879839 , 0.00810252, 0.9917418 , 0.99795693, 0.99744034,
#        0.9969435 , 0.0024374 , 0.92142904, 0.9966154 , 0.9972078 ,
#        0.00219718, 0.06857699, 0.00277114, 0.9894245 , 0.00447836,
# ...
